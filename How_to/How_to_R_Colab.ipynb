# %% [markdown]
# <a href="https://colab.research.google.com/github/BragatteMAS/BioinfoEstrutural/blob/master/How_to/How_to_R_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to R in Colab
# [Colab with R option](https://colab.to/r)
#
#         Ao abrir a nova página o ambiente R já estará pré definido
#
# ![r.png](data:image/png;base64,...)![R2WgR.png](data:image/png;base64,...)
#
# Created by Bragatte 202102061922

# %% [markdown]
# # R code

# %% [markdown]
# ## chamando dados

# %%
#lendo csv
disf_eret <- read.csv("/content/bd_pre_pos.csv", sep = ";",header = 1)
disf_eret
# Out:
#    Grupo       Pacientes IIEF_1 IIEF_2 IIEF_grav_1 IIEF_grav_2 OABV8_1 OABV8_2
# 1  controle     1        6       7     4           4            8       2
# 2  controle     2        6       5     4           4           17       5
# 3  controle     4        5       6     4           4           16       4
# 4  controle     8        7       8     4           3           21      28
# 5  controle    10        7      11     4           3           10       6
# 6  controle    12        7       5     4           4           40      10
# 7  intervencao  3        8      13     3           2           16       5
# 8  intervencao  5        7       9     4           2           11       5
# 9  intervencao  6        6       7     4           4            2       0
# 10 intervencao  7        6       8     4           3           22       6
# 11 intervencao  9        7       7     4           4           15       6
# 12 intervencao 11        9      13     3           2           29       9
# ...

# %% [markdown]
# ## Relação do X2 entre duas colunas

# %%
x2 = table(disf_eret$Grupo, disf_eret$IIEF_grav_2)
x2
# Out:
#
#               2 3 4
#   controle    0 2 4
#   intervencao 4 1 2

# %%
chisq.test(x2)
# Out:
# Warning message in chisq.test(x2):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  x2
# X-squared = 4.9524, df = 2, p-value = 0.08406

# %%
chisq.test(x2)$p.value
# Out:
# Warning message in chisq.test(x2):
# “Chi-squared approximation may be incorrect”
# [1] 0.08406286

# %%
##segundo método
summary(x2)
# Out:
# Number of cases in table: 13
# Number of factors: 2
# Test for independence of all factors:
# 	Chisq = 4.952, df = 2, p-value = 0.08406
# 	Chi-squared approximation may be incorrect
